# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##### This project is an exploration of the Kenyan population census data of 2019

# %% [markdown]
# # Loading and cleaning Data

# %% [markdown]
# #### 1st dataset: Kenya population density per county per Land area

# %%
df = pd.read_csv("https://open.africa/dataset/9b94fe50-9d75-4b92-be00-6354c6e6cc88/resource/da01bf5a-61d7-43e5-9009-7b54e249e984/download/kenya-population-land-area-population-density_by_county.csv")

# %%
df.head(15)
# Out:
#                                            Unnamed: 0  Unnamed: 1  \
# 0   Distribution of Population, Land Area and Popu...         NaN
# 1   Source: 2019 Kenya Population and Housing Cens...         NaN
# 2   https://www.knbs.or.ke/?wpdmpro=2019-kenya-pop...         NaN
# 3   Population, Land area, Population density, Cou...         NaN
# 4                                                 NaN         NaN
# 5                                                name  Population
# 6                                               Kenya    47564296
# 7                                             Mombasa     1208333
# 8                                               Kwale      866820
# 9                                              Kilifi     1453787
# 10                                         Tana River      315943
# 11                                               Lamu      143920
# 12                                       Taita-Taveta      340671
# 13                                            Garissa      841353
# 14                                              Wajir      781263
#
#             Unnamed: 2                           Unnamed: 3
# 0                  NaN                                  NaN
# 1                  NaN                                  NaN
# 2                  NaN                                  NaN
# 3                  NaN                                  NaN
# 4                  NaN                                  NaN
# 5   Land Area (Sq. Km)  Population Density (No. per Sq. Km)
# 6             580876.3                                   82
# 7                219.9                                 5495
# 8               8267.1                                  105
# 9              12539.7                                  116
# 10             37950.5                                    8
# 11              6253.3                                   23
# 12               17152                                   20
# 13               44736                                   19
# 14             56773.1                                   14

# %%
#Labelling the columns
df.columns=('County_Name','Pop_Size','Land_Area(Sq.Km)','Pop_density_per_Sqkm')

# %%
df.head(15)
# Out:
#                                           County_Name    Pop_Size  \
# 0   Distribution of Population, Land Area and Popu...         NaN
# 1   Source: 2019 Kenya Population and Housing Cens...         NaN
# 2   https://www.knbs.or.ke/?wpdmpro=2019-kenya-pop...         NaN
# 3   Population, Land area, Population density, Cou...         NaN
# 4                                                 NaN         NaN
# 5                                                name  Population
# 6                                               Kenya    47564296
# 7                                             Mombasa     1208333
# 8                                               Kwale      866820
# 9                                              Kilifi     1453787
# 10                                         Tana River      315943
# 11                                               Lamu      143920
# 12                                       Taita-Taveta      340671
# 13                                            Garissa      841353
# 14                                              Wajir      781263
#
#       Land_Area(Sq.Km)                 Pop_density_per_Sqkm
# 0                  NaN                                  NaN
# 1                  NaN                                  NaN
# 2                  NaN                                  NaN
# 3                  NaN                                  NaN
# 4                  NaN                                  NaN
# 5   Land Area (Sq. Km)  Population Density (No. per Sq. Km)
# 6             580876.3                                   82
# 7                219.9                                 5495
# 8               8267.1                                  105
# 9              12539.7                                  116
# 10             37950.5                                    8
# 11              6253.3                                   23
# 12               17152                                   20
# 13               44736                                   19
# 14             56773.1                                   14

# %%
#deleting the first few rows that have unnecesary information
df.drop(df.index[:7], inplace=True)

# %%
df.head()
# Out:
#    County_Name Pop_Size Land_Area(Sq.Km) Pop_density_per_Sqkm
# 7      Mombasa  1208333            219.9                 5495
# 8        Kwale   866820           8267.1                  105
# 9       Kilifi  1453787          12539.7                  116
# 10  Tana River   315943          37950.5                    8
# 11        Lamu   143920           6253.3                   23

# %%
df
# Out:
#         County_Name Pop_Size Land_Area(Sq.Km) Pop_density_per_Sqkm
# 7           Mombasa  1208333            219.9                 5495
# 8             Kwale   866820           8267.1                  105
# 9            Kilifi  1453787          12539.7                  116
# 10       Tana River   315943          37950.5                    8
# 11             Lamu   143920           6253.3                   23
# 12     Taita-Taveta   340671            17152                   20
# 13          Garissa   841353            44736                   19
# 14            Wajir   781263          56773.1                   14
# 15          Mandera   867457          25939.8                   33
# 16         Marsabit   459785          70944.1                    6
# 17           Isiolo   268002          25350.6                   11
# 18             Meru  1545714           7006.3                  221
# 19    Tharaka-Nithi   393177           2564.4                  153
# 20             Embu   608599           2820.7                  216
# 21            Kitui  1136187          30429.5                   37
# 22         Machakos  1421932           6042.7                  235
# 23          Makueni   987653           8169.8                  121
# 24        Nyandarua   638289           3285.7                  194
# 25            Nyeri   759164             3325                  228
# 26        Kirinyaga   610411           1478.3                  413
# 27         Murang'a  1056640           2524.2                  419
# 28           Kiambu  2417735           2538.6                  952
# 29          Turkana   926976          68232.9                   14
# 30       West Pokot   621241           9123.2                   68
# 31          Samburu   310327          21065.1                   15
# 32      Trans Nzoia   990341           2495.2                  397
# 33      Uasin Gishu  1163186           3392.2                  343
# 34  Elgeyo-Marakwet   454480             3032                  150
# 35            Nandi   885711           2855.8                  310
# 36          Baringo   666763          10976.4                   61
# 37         Laikipia   518560           9532.2                   54
# 38           Nakuru  2162202           7462.4                  290
# 39            Narok  1157873          17950.3                   65
# 40          Kajiado  1117840          21871.1                   51
# 41          Kericho   901777           2436.1                  370
# 42            Bomet   875689           2530.9                  346
# 43         Kakamega  1867579             3020                  618
# 44           Vihiga   590013            563.8                 1047
# 45          Bungoma  1670570           3023.9                  552
# 46            Busia   893681           1696.3                  527
# 47            Siaya   993183           2529.8                  393
# 48           Kisumu  1155574           2085.4                  554
# 49         Homa Bay  1131950           3152.5                  359
# 50           Migori  1116436           2613.5                  427
# 51            Kisii  1266860             1323                  958
# 52          Nyamira   605576            897.3                  675
# 53          Nairobi  4397073            703.9                 6247

# %%
#resetting the index
df.reset_index(drop= True, inplace=True)

# %%
df
# Out:
#         County_Name Pop_Size Land_Area(Sq.Km) Pop_density_per_Sqkm
# 0           Mombasa  1208333            219.9                 5495
# 1             Kwale   866820           8267.1                  105
# 2            Kilifi  1453787          12539.7                  116
# 3        Tana River   315943          37950.5                    8
# 4              Lamu   143920           6253.3                   23
# 5      Taita-Taveta   340671            17152                   20
# 6           Garissa   841353            44736                   19
# 7             Wajir   781263          56773.1                   14
# 8           Mandera   867457          25939.8                   33
# 9          Marsabit   459785          70944.1                    6
# 10           Isiolo   268002          25350.6                   11
# 11             Meru  1545714           7006.3                  221
# 12    Tharaka-Nithi   393177           2564.4                  153
# 13             Embu   608599           2820.7                  216
# 14            Kitui  1136187          30429.5                   37
# 15         Machakos  1421932           6042.7                  235
# 16          Makueni   987653           8169.8                  121
# 17        Nyandarua   638289           3285.7                  194
# 18            Nyeri   759164             3325                  228
# 19        Kirinyaga   610411           1478.3                  413
# 20         Murang'a  1056640           2524.2                  419
# 21           Kiambu  2417735           2538.6                  952
# 22          Turkana   926976          68232.9                   14
# 23       West Pokot   621241           9123.2                   68
# 24          Samburu   310327          21065.1                   15
# 25      Trans Nzoia   990341           2495.2                  397
# 26      Uasin Gishu  1163186           3392.2                  343
# 27  Elgeyo-Marakwet   454480             3032                  150
# 28            Nandi   885711           2855.8                  310
# 29          Baringo   666763          10976.4                   61
# 30         Laikipia   518560           9532.2                   54
# 31           Nakuru  2162202           7462.4                  290
# 32            Narok  1157873          17950.3                   65
# 33          Kajiado  1117840          21871.1                   51
# 34          Kericho   901777           2436.1                  370
# 35            Bomet   875689           2530.9                  346
# 36         Kakamega  1867579             3020                  618
# 37           Vihiga   590013            563.8                 1047
# 38          Bungoma  1670570           3023.9                  552
# 39            Busia   893681           1696.3                  527
# 40            Siaya   993183           2529.8                  393
# 41           Kisumu  1155574           2085.4                  554
# 42         Homa Bay  1131950           3152.5                  359
# 43           Migori  1116436           2613.5                  427
# 44            Kisii  1266860             1323                  958
# 45          Nyamira   605576            897.3                  675
# 46          Nairobi  4397073            703.9                 6247

# %% [markdown]
# ### 2nd Dataset

# %% [markdown]
# #### Distribution of population by Sex and County

# %%
df2=pd.read_csv('https://open.africa/dataset/9b94fe50-9d75-4b92-be00-6354c6e6cc88/resource/68dc2815-c9de-47ec-92d9-61f0be213ed8/download/distribution-of-population-by-sex-and-county-2019-census-volume-ii.csv')

# %%
df2.head()
# Out:
#        County     Total     Male     Female  Sex Intersex
# 0       Kenya  47564296  23548056  24014716          1524
# 1     Mombasa   1208333    610257    598046            30
# 2       Kwale    866820    425121    441681            18
# 3      Kilifi   1453787    704089    749673            25
# 4  Tana River    315943    158550    157391             2

# %%
df2.drop(df2.index[0], inplace=True)

# %%
df2.head()
# Out:
#        County    Total   Male   Female  Sex Intersex
# 1     Mombasa  1208333  610257  598046            30
# 2       Kwale   866820  425121  441681            18
# 3      Kilifi  1453787  704089  749673            25
# 4  Tana River   315943  158550  157391             2
# 5        Lamu   143920   76103   67813             4

# %%
df2.reset_index(drop= True, inplace=True)

# %%
df2.head()
# Out:
#        County    Total   Male   Female  Sex Intersex
# 0     Mombasa  1208333  610257  598046            30
# 1       Kwale   866820  425121  441681            18
# 2      Kilifi  1453787  704089  749673            25
# 3  Tana River   315943  158550  157391             2
# 4        Lamu   143920   76103   67813             4

# %% [markdown]
# ### 3rd dataset:

# %% [markdown]
# #### Distribution of population, number of Housholds and Average household size by county

# %%
df3=pd.read_csv("https://open.africa/dataset/9b94fe50-9d75-4b92-be00-6354c6e6cc88/resource/111a3d9d-c676-4d5a-9600-d5acb1250b87/download/population-houseshold-data.csv")

# %%
df3.head(15)
# Out:
#                                            Unnamed: 0  Unnamed: 1  \
# 0   Distribution of Population, Number of Househol...         NaN
# 1   Source: 2019 Kenya Population and Housing Cens...         NaN
# 2   https://www.knbs.or.ke/?wpdmpro=2019-kenya-pop...         NaN
# 3   Population, Households, Household size, County...         NaN
# 4                                                 NaN         NaN
# 5                                                name  Population
# 6                                               Kenya    47213282
# 7                                             Mombasa     1190987
# 8                                               Kwale      858748
# 9                                              Kilifi     1440958
# 10                                         Tana River      314710
# 11                                               Lamu      141909
# 12                                       Taita-Taveta      335747
# 13                                            Garissa      835482
# 14                                              Wajir      775302
#
#           Unnamed: 2          Unnamed: 3
# 0                NaN                 NaN
# 1                NaN                 NaN
# 2                NaN                 NaN
# 3                NaN                 NaN
# 4                NaN                 NaN
# 5   No.of Households  Avg Household size
# 6           12143913                  39
# 7             378422                  31
# 8             173176                  50
# 9             298472                  48
# 10             68242                  46
# 11             37963                  37
# 12             96429                  35
# 13            141394                  59
# 14            127932                  61

# %%
df3.columns=('County_Name','Pop_Size','No. of Households','Avg Household Size')

# %%
df3.drop(df3.index[:7], inplace=True)

# %%
df3.reset_index(drop= True, inplace=True)

# %%
df3.head()
# Out:
#   County_Name Pop_Size No. of Households Avg Household Size
# 0     Mombasa  1190987            378422                 31
# 1       Kwale   858748            173176                 50
# 2      Kilifi  1440958            298472                 48
# 3  Tana River   314710             68242                 46
# 4        Lamu   141909             37963                 37

# %% [markdown]
# ### 4th Dataset

# %% [markdown]
# #### Distribution of Population by Age and Sex

# %%
df4=pd.read_csv("https://open.africa/dataset/9b94fe50-9d75-4b92-be00-6354c6e6cc88/resource/85b587f4-48c5-4fa5-b15b-c3f97942f66a/download/distribution-of-population-by-age-and-sex-kenya-2019-census-volume-iii.csv")

# %%
df4.head(20)
# Out:
#        Age        Male      Female Intersex  Unnamed: 4  Unnamed: 5
# 0    Total  23,548,056  24,014,716    1,524         NaN         NaN
# 1        0     552,508     552,528       38         NaN         NaN
# 2        1     580,856     573,920       29         NaN         NaN
# 3        2     614,005     610,705       33         NaN         NaN
# 4        3     619,989     621,941       26         NaN         NaN
# 5        4     638,986     627,675       28         NaN         NaN
# 6    0 - 4   3,006,344   2,986,769      154         NaN         NaN
# 7        5     626,157     610,459       40         NaN         NaN
# 8        6     635,924     635,942       30         NaN         NaN
# 9        7     609,615     601,301       24         NaN         NaN
# 10       8     618,618     616,833       46         NaN         NaN
# 11       9     626,637     620,981       36         NaN         NaN
# 12   5 - 9   3,116,951   3,085,516      176         NaN         NaN
# 13      10     700,526     678,721       33         NaN         NaN
# 14      11     573,757     591,394       33         NaN         NaN
# 15      12     686,954     648,485       36         NaN         NaN
# 16      13     635,152     628,630       29         NaN         NaN
# 17      14     613,371     588,912       39         NaN         NaN
# 18  10 -14   3,209,760   3,136,142      170         NaN         NaN
# 19      15     611,376     583,931       34         NaN         NaN

# %%
df4.tail()
# Out:
#             Age   Male  Female Intersex  Unnamed: 4  Unnamed: 5
# 118          98  1,137   2,026        -         NaN         NaN
# 119          99  1,856   4,734        -         NaN         NaN
# 120       95-99  9,770  18,236        -         NaN         NaN
# 121        100+  3,876  10,164        -         NaN         NaN
# 122  Not Stated    385     297        5         NaN         NaN

# %% [markdown]
# #### drop columns from df4 that have all Null values

# %%
df4.dropna(axis=1, inplace=True)

# %%
df4
# Out:
#             Age        Male      Female Intersex
# 0         Total  23,548,056  24,014,716    1,524
# 1             0     552,508     552,528       38
# 2             1     580,856     573,920       29
# 3             2     614,005     610,705       33
# 4             3     619,989     621,941       26
# ..          ...         ...         ...      ...
# 118          98       1,137       2,026        -
# 119          99       1,856       4,734        -
# 120       95-99       9,770      18,236        -
# 121        100+       3,876      10,164        -
# 122  Not Stated         385         297        5
#
# [123 rows x 4 columns]

# %% [markdown]
# #### Working with df1,2 and 3 first as they have common columns
#
# ##### joining columns, changing column datatypes,checking for Null values

# %%
df.head()
# Out:
#   County_Name Pop_Size Land_Area(Sq.Km) Pop_density_per_Sqkm
# 0     Mombasa  1208333            219.9                 5495
# 1       Kwale   866820           8267.1                  105
# 2      Kilifi  1453787          12539.7                  116
# 3  Tana River   315943          37950.5                    8
# 4        Lamu   143920           6253.3                   23

# %%
df2.head()
# Out:
#        County    Total   Male   Female  Sex Intersex
# 0     Mombasa  1208333  610257  598046            30
# 1       Kwale   866820  425121  441681            18
# 2      Kilifi  1453787  704089  749673            25
# 3  Tana River   315943  158550  157391             2
# 4        Lamu   143920   76103   67813             4

# %%
df3.head()
# Out:
#   County_Name Pop_Size No. of Households Avg Household Size
# 0     Mombasa  1190987            378422                 31
# 1       Kwale   858748            173176                 50
# 2      Kilifi  1440958            298472                 48
# 3  Tana River   314710             68242                 46
# 4        Lamu   141909             37963                 37

# %%
df2.columns.values.tolist()
# Out:
# ['County', 'Total', 'Male ', 'Female', 'Sex Intersex']

# %%
df['Male']=df2['Male ']
df['Female']=df2['Female']
df['Intersex']=df2['Sex Intersex']

# %%
df.head()
# Out:
#   County_Name Pop_Size Land_Area(Sq.Km) Pop_density_per_Sqkm    Male  Female  \
# 0     Mombasa  1208333            219.9                 5495  610257  598046
# 1       Kwale   866820           8267.1                  105  425121  441681
# 2      Kilifi  1453787          12539.7                  116  704089  749673
# 3  Tana River   315943          37950.5                    8  158550  157391
# 4        Lamu   143920           6253.3                   23   76103   67813
#
#    Intersex
# 0        30
# 1        18
# 2        25
# 3         2
# 4         4

# %%
df3.columns.values.tolist()
#df3.columns.get_loc('No. of Households')
# Out:
# ['County_Name', 'Pop_Size', 'No. of Households', 'Avg Household Size']

# %%
df['No_of_Households']=df3['No. of Households']
df['Avg Household Size']=df3['Avg Household Size']

# %%
df
# Out:
#         County_Name Pop_Size Land_Area(Sq.Km) Pop_density_per_Sqkm     Male  \
# 0           Mombasa  1208333            219.9                 5495   610257
# 1             Kwale   866820           8267.1                  105   425121
# 2            Kilifi  1453787          12539.7                  116   704089
# 3        Tana River   315943          37950.5                    8   158550
# 4              Lamu   143920           6253.3                   23    76103
# 5      Taita-Taveta   340671            17152                   20   173337
# 6           Garissa   841353            44736                   19   458975
# 7             Wajir   781263          56773.1                   14   415374
# 8           Mandera   867457          25939.8                   33   434976
# 9          Marsabit   459785          70944.1                    6   243548
# 10           Isiolo   268002          25350.6                   11   139510
# 11             Meru  1545714           7006.3                  221   767698
# 12    Tharaka-Nithi   393177           2564.4                  153   193764
# 13             Embu   608599           2820.7                  216   304208
# 14            Kitui  1136187          30429.5                   37   549003
# 15         Machakos  1421932           6042.7                  235   710707
# 16          Makueni   987653           8169.8                  121   489691
# 17        Nyandarua   638289           3285.7                  194   315022
# 18            Nyeri   759164             3325                  228   374288
# 19        Kirinyaga   610411           1478.3                  413   302011
# 20         Murang'a  1056640           2524.2                  419   523940
# 21           Kiambu  2417735           2538.6                  952  1187146
# 22          Turkana   926976          68232.9                   14   478087
# 23       West Pokot   621241           9123.2                   68   307013
# 24          Samburu   310327          21065.1                   15   156774
# 25      Trans Nzoia   990341           2495.2                  397   489107
# 26      Uasin Gishu  1163186           3392.2                  343   580269
# 27  Elgeyo-Marakwet   454480             3032                  150   227317
# 28            Nandi   885711           2855.8                  310   441259
# 29          Baringo   666763          10976.4                   61   336322
# 30         Laikipia   518560           9532.2                   54   259440
# 31           Nakuru  2162202           7462.4                  290  1077272
# 32            Narok  1157873          17950.3                   65   579042
# 33          Kajiado  1117840          21871.1                   51   557098
# 34          Kericho   901777           2436.1                  370   450741
# 35            Bomet   875689           2530.9                  346   434287
# 36         Kakamega  1867579             3020                  618   897133
# 37           Vihiga   590013            563.8                 1047   283678
# 38          Bungoma  1670570           3023.9                  552   812146
# 39            Busia   893681           1696.3                  527   426252
# 40            Siaya   993183           2529.8                  393   471669
# 41           Kisumu  1155574           2085.4                  554   560942
# 42         Homa Bay  1131950           3152.5                  359   539560
# 43           Migori  1116436           2613.5                  427   536187
# 44            Kisii  1266860             1323                  958   605784
# 45          Nyamira   605576            897.3                  675   290907
# 46          Nairobi  4397073            703.9                 6247  2192452
#
#      Female  Intersex No_of_Households Avg Household Size
# 0    598046        30           378422                 31
# 1    441681        18           173176                 50
# 2    749673        25           298472                 48
# 3    157391         2            68242                 46
# 4     67813         4            37963                 37
# 5    167327         7            96429                 35
# 6    382344        34           141394                 59
# 7    365840        49           127932                 61
# 8    432444        37           125763                 69
# 9    216219        18            77495                 58
# 10   128483         9            58072                 46
# 11   777975        41           426360                 36
# 12   199406         7           109860                 36
# 13   304367        24           182743                 33
# 14   587151        33           262942                 43
# 15   711191        34           402466                 35
# 16   497942        20           244669                 40
# 17   323247        20           179686                 35
# 18   384845        31           248050                 30
# 19   308369        31           204188                 30
# 20   532669        31           318105                 33
# 21  1230454       135           795241                 30
# 22   448868        21           164519                 56
# 23   314213        15           116182                 53
# 24   153546         7            65910                 47
# 25   501206        28           223808                 44
# 26   582889        28           304943                 38
# 27   227151        12            99861                 45
# 28   444430        22           199426                 44
# 29   330428        13           142518                 47
# 30   259102        18           149271                 34
# 31  1084835        95           616046                 35
# 32   578805        26           241125                 48
# 33   560704        38           316179                 35
# 34   451008        28           206036                 44
# 35   441379        23           187641                 47
# 36   970406        40           433207                 43
# 37   306323        12           143365                 41
# 38   858389        35           358796                 46
# 39   467401        28           198152                 45
# 40   521496        18           250698                 39
# 41   594609        23           300745                 38
# 42   592367        23           262036                 43
# 43   580214        35           240168                 46
# 44   661038        38           308054                 41
# 45   314656        13           150669                 40
# 46  2204376       245          1506888                 29

# %%
#writing df to an excel file to save it as a backup

df.to_csv('popcensusdata1.csv')

# %%
df.describe()
# Out:
#                Male        Female    Intersex
# count  4.700000e+01  4.700000e+01   47.000000
# mean   5.010225e+05  5.109514e+05   32.425532
# std    3.423677e+05  3.513158e+05   38.490961
# min    7.610300e+04  6.781300e+04    2.000000
# 25%    3.031095e+05  3.112910e+05   18.000000
# 50%    4.507410e+05  4.488680e+05   25.000000
# 75%    5.699920e+05  5.897590e+05   34.000000
# max    2.192452e+06  2.204376e+06  245.000000

# %%
df['Pop_density_per_Sqkm'].describe()
# Out:
# count     47
# unique    46
# top       14
# freq       2
# Name: Pop_density_per_Sqkm, dtype: object

# %%
df.dtypes
# Out:
# County_Name             object
# Pop_Size                object
# Land_Area(Sq.Km)        object
# Pop_density_per_Sqkm    object
# Male                     int64
# Female                   int64
# Intersex                 int64
# No_of_Households        object
# Avg Household Size      object
# dtype: object

# %%
#convert column to numeric
df[["Pop_Size","Land_Area(Sq.Km)","Pop_density_per_Sqkm","No_of_Households","Avg Household Size"]]=df[["Pop_Size","Land_Area(Sq.Km)","Pop_density_per_Sqkm","No_of_Households","Avg Household Size"]].apply(pd.to_numeric)

# %%
df.dtypes
# Out:
# County_Name              object
# Pop_Size                  int64
# Land_Area(Sq.Km)        float64
# Pop_density_per_Sqkm      int64
# Male                      int64
# Female                    int64
# Intersex                  int64
# No_of_Households          int64
# Avg Household Size        int64
# dtype: object

# %%
df.describe()
# Out:
#            Pop_Size  Land_Area(Sq.Km)  Pop_density_per_Sqkm          Male  \
# count  4.700000e+01         47.000000             47.000000  4.700000e+01
# mean   1.012006e+06      12359.074468            509.148936  5.010225e+05
# std    6.932427e+05      17366.002689           1175.429468  3.423677e+05
# min    1.439200e+05        219.900000              6.000000  7.610300e+04
# 25%    6.095050e+05       2530.350000             52.500000  3.031095e+05
# 50%    8.936810e+05       3325.000000            221.000000  4.507410e+05
# 75%    1.156724e+06      14845.850000            416.000000  5.699920e+05
# max    4.397073e+06      70944.100000           6247.000000  2.192452e+06
#
#              Female    Intersex  No_of_Households  Avg Household Size
# count  4.700000e+01   47.000000      4.700000e+01           47.000000
# mean   5.109514e+05   32.425532      2.583811e+05           42.319149
# std    3.513158e+05   38.490961      2.344552e+05            8.841863
# min    6.781300e+04    2.000000      3.796300e+04           29.000000
# 25%    3.112910e+05   18.000000      1.419560e+05           35.000000
# 50%    4.488680e+05   25.000000      2.041880e+05           43.000000
# 75%    5.897590e+05   34.000000      3.028440e+05           46.500000
# max    2.204376e+06  245.000000      1.506888e+06           69.000000

# %%
#checking for any null values
df.isnull().values.any()
# Out:
# False

# %%
#reading from the cleaned csv file to work with data stored locally and also not have to run entire notebook each time

df=pd.read_csv('popcensusdata1.csv')

# %%
df
# Out:
#     Unnamed: 0      County_Name  Pop_Size  Land_Area(Sq.Km)  \
# 0            0          Mombasa   1208333             219.9
# 1            1            Kwale    866820            8267.1
# 2            2           Kilifi   1453787           12539.7
# 3            3       Tana River    315943           37950.5
# 4            4             Lamu    143920            6253.3
# 5            5     Taita-Taveta    340671           17152.0
# 6            6          Garissa    841353           44736.0
# 7            7            Wajir    781263           56773.1
# 8            8          Mandera    867457           25939.8
# 9            9         Marsabit    459785           70944.1
# 10          10           Isiolo    268002           25350.6
# 11          11             Meru   1545714            7006.3
# 12          12    Tharaka-Nithi    393177            2564.4
# 13          13             Embu    608599            2820.7
# 14          14            Kitui   1136187           30429.5
# 15          15         Machakos   1421932            6042.7
# 16          16          Makueni    987653            8169.8
# 17          17        Nyandarua    638289            3285.7
# 18          18            Nyeri    759164            3325.0
# 19          19        Kirinyaga    610411            1478.3
# 20          20         Murang'a   1056640            2524.2
# 21          21           Kiambu   2417735            2538.6
# 22          22          Turkana    926976           68232.9
# 23          23       West Pokot    621241            9123.2
# 24          24          Samburu    310327           21065.1
# 25          25      Trans Nzoia    990341            2495.2
# 26          26      Uasin Gishu   1163186            3392.2
# 27          27  Elgeyo-Marakwet    454480            3032.0
# 28          28            Nandi    885711            2855.8
# 29          29          Baringo    666763           10976.4
# 30          30         Laikipia    518560            9532.2
# 31          31           Nakuru   2162202            7462.4
# 32          32            Narok   1157873           17950.3
# 33          33          Kajiado   1117840           21871.1
# 34          34          Kericho    901777            2436.1
# 35          35            Bomet    875689            2530.9
# 36          36         Kakamega   1867579            3020.0
# 37          37           Vihiga    590013             563.8
# 38          38          Bungoma   1670570            3023.9
# 39          39            Busia    893681            1696.3
# 40          40            Siaya    993183            2529.8
# 41          41           Kisumu   1155574            2085.4
# 42          42         Homa Bay   1131950            3152.5
# 43          43           Migori   1116436            2613.5
# 44          44            Kisii   1266860            1323.0
# 45          45          Nyamira    605576             897.3
# 46          46          Nairobi   4397073             703.9
#
#     Pop_density_per_Sqkm     Male   Female  Intersex  No_of_Households  \
# 0                   5495   610257   598046        30            378422
# 1                    105   425121   441681        18            173176
# 2                    116   704089   749673        25            298472
# 3                      8   158550   157391         2             68242
# 4                     23    76103    67813         4             37963
# 5                     20   173337   167327         7             96429
# 6                     19   458975   382344        34            141394
# 7                     14   415374   365840        49            127932
# 8                     33   434976   432444        37            125763
# 9                      6   243548   216219        18             77495
# 10                    11   139510   128483         9             58072
# 11                   221   767698   777975        41            426360
# 12                   153   193764   199406         7            109860
# 13                   216   304208   304367        24            182743
# 14                    37   549003   587151        33            262942
# 15                   235   710707   711191        34            402466
# 16                   121   489691   497942        20            244669
# 17                   194   315022   323247        20            179686
# 18                   228   374288   384845        31            248050
# 19                   413   302011   308369        31            204188
# 20                   419   523940   532669        31            318105
# 21                   952  1187146  1230454       135            795241
# 22                    14   478087   448868        21            164519
# 23                    68   307013   314213        15            116182
# 24                    15   156774   153546         7             65910
# 25                   397   489107   501206        28            223808
# 26                   343   580269   582889        28            304943
# 27                   150   227317   227151        12             99861
# 28                   310   441259   444430        22            199426
# 29                    61   336322   330428        13            142518
# 30                    54   259440   259102        18            149271
# 31                   290  1077272  1084835        95            616046
# 32                    65   579042   578805        26            241125
# 33                    51   557098   560704        38            316179
# 34                   370   450741   451008        28            206036
# 35                   346   434287   441379        23            187641
# 36                   618   897133   970406        40            433207
# 37                  1047   283678   306323        12            143365
# 38                   552   812146   858389        35            358796
# 39                   527   426252   467401        28            198152
# 40                   393   471669   521496        18            250698
# 41                   554   560942   594609        23            300745
# 42                   359   539560   592367        23            262036
# 43                   427   536187   580214        35            240168
# 44                   958   605784   661038        38            308054
# 45                   675   290907   314656        13            150669
# 46                  6247  2192452  2204376       245           1506888
#
#     Avg Household Size
# 0                   31
# 1                   50
# 2                   48
# 3                   46
# 4                   37
# 5                   35
# 6                   59
# 7                   61
# 8                   69
# 9                   58
# 10                  46
# 11                  36
# 12                  36
# 13                  33
# 14                  43
# 15                  35
# 16                  40
# 17                  35
# 18                  30
# 19                  30
# 20                  33
# 21                  30
# 22                  56
# 23                  53
# 24                  47
# 25                  44
# 26                  38
# 27                  45
# 28                  44
# 29                  47
# 30                  34
# 31                  35
# 32                  48
# 33                  35
# 34                  44
# 35                  47
# 36                  43
# 37                  41
# 38                  46
# 39                  45
# 40                  39
# 41                  38
# 42                  43
# 43                  46
# 44                  41
# 45                  40
# 46                  29

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Population Density per county - Bar graph

# %%
bins=[500000,1000000,1500000,2000000,2500000,3000000,3500000,4000000,4500000]
df.plot(kind='bar', x='County_Name',y='Pop_Size', width=0.5)
#plt.bar(df['County_Name'],df['Pop_Size'],width=0.5)
plt.yticks(bins)
plt.title ('Population density per county County')
plt.xlabel('Counties')
plt.ylabel('Population density (million)')
plt.figure(figsize=(300,6))
#plt.xticks(fontsize=0.5)
#plt.xticks(rotation=25)


#plt.tick_params(axis='x', which='major', labelsize=3)
plt.show()

# %%
# from the bar graph the most populous county in Kenya is Nairobi, followed by Kiambu, Nakuru and Kakamega
# The least populous county is Lamu, followed by isiolo, Tana River,Taita-Taveta, samburu, Tharaka Nithi
# Interesting to note that Tharaka Nithi county is among the least populous counties contrary to popular belief

# %%
#Land area per county
df.plot(kind='bar', x='County_Name',y='Land_Area(Sq.Km)', width=0.5)
# Out:
# <AxesSubplot:xlabel='County_Name'>

# %%
#Turkana and Marsabit counties cover the largest area per sqm followed by

# %%
#Population (density per sqkm) per county
df.plot(kind='bar', x='County_Name',y='Pop_density_per_Sqkm', width=0.5)
# Out:
# <AxesSubplot:xlabel='County_Name'>
