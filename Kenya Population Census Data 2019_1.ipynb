# %% [markdown]
# ### 1.0 Introduction
# The Kenyan government has carried out a population census every 10 years since 1948. The latest census was done in 2019 and it recorded a population of 47.5 million. This project utilizes the population and housing census data of 2019 to explore the Kenyan population characteristis.This is achieved by plotting visualizations with the datasets. The data is composed of several sets and this project utilizes just a few because of time limitation. The datasets were obtained from the africaopendata.org portal. Four datasets were used name: 'Kenya population density per county per Land area','Distribution of population by Sex and County','Distribution of population, number of Housholds and Average household size by county','Distribution of Population by Age and Sex'

# %% [markdown]
# ### 2.0 Data Cleaning
# The first step in this exploration is the cleaning process. Data cleaning  involves formatting of the datasets, removing duplicates, handling missing data, removing incorrect entries and performing necessary data conversions.
# On the 4 datasets, i rename columns,drop rows with null values,reset indexes, correct inaccurate data, perform datatype conversions and join some of the datasets.This can be seen in the next section.

# %% [markdown]
# ###### Data loading and cleaning

# %%
# starting by importing necessary libraries
import pandas as pd
import numpy as np

# %% [markdown]
# #### 1st dataset: Kenya population density per county per Land area

# %%
df = pd.read_csv("https://open.africa/dataset/9b94fe50-9d75-4b92-be00-6354c6e6cc88/resource/da01bf5a-61d7-43e5-9009-7b54e249e984/download/kenya-population-land-area-population-density_by_county.csv")

# %%
df.head(15)
# Out:
#                                            Unnamed: 0  Unnamed: 1  \
# 0   Distribution of Population, Land Area and Popu...         NaN
# 1   Source: 2019 Kenya Population and Housing Cens...         NaN
# 2   https://www.knbs.or.ke/?wpdmpro=2019-kenya-pop...         NaN
# 3   Population, Land area, Population density, Cou...         NaN
# 4                                                 NaN         NaN
# 5                                                name  Population
# 6                                               Kenya    47564296
# 7                                             Mombasa     1208333
# 8                                               Kwale      866820
# 9                                              Kilifi     1453787
# 10                                         Tana River      315943
# 11                                               Lamu      143920
# 12                                       Taita-Taveta      340671
# ...

# %%
#Labelling the columns
df.columns=('County_Name','Pop_Size','Land_Area(Sq.Km)','Pop_density_per_Sqkm')

# %%
df.head(15)
# Out:
#                                           County_Name    Pop_Size  \
# 0   Distribution of Population, Land Area and Popu...         NaN
# 1   Source: 2019 Kenya Population and Housing Cens...         NaN
# 2   https://www.knbs.or.ke/?wpdmpro=2019-kenya-pop...         NaN
# 3   Population, Land area, Population density, Cou...         NaN
# 4                                                 NaN         NaN
# 5                                                name  Population
# 6                                               Kenya    47564296
# 7                                             Mombasa     1208333
# 8                                               Kwale      866820
# 9                                              Kilifi     1453787
# 10                                         Tana River      315943
# 11                                               Lamu      143920
# 12                                       Taita-Taveta      340671
# ...

# %%
#deleting the first few rows that have unnecesary information
df.drop(df.index[:7], inplace=True)

# %%
df.head()
# Out:
#    County_Name Pop_Size Land_Area(Sq.Km) Pop_density_per_Sqkm
# 7      Mombasa  1208333            219.9                 5495
# 8        Kwale   866820           8267.1                  105
# 9       Kilifi  1453787          12539.7                  116
# 10  Tana River   315943          37950.5                    8
# 11        Lamu   143920           6253.3                   23

# %%
df
# Out:
#         County_Name Pop_Size Land_Area(Sq.Km) Pop_density_per_Sqkm
# 7           Mombasa  1208333            219.9                 5495
# 8             Kwale   866820           8267.1                  105
# 9            Kilifi  1453787          12539.7                  116
# 10       Tana River   315943          37950.5                    8
# 11             Lamu   143920           6253.3                   23
# 12     Taita-Taveta   340671            17152                   20
# 13          Garissa   841353            44736                   19
# 14            Wajir   781263          56773.1                   14
# 15          Mandera   867457          25939.8                   33
# 16         Marsabit   459785          70944.1                    6
# 17           Isiolo   268002          25350.6                   11
# 18             Meru  1545714           7006.3                  221
# 19    Tharaka-Nithi   393177           2564.4                  153
# ...

# %%
#resetting the index
df.reset_index(drop= True, inplace=True)

# %%
df
# Out:
#         County_Name Pop_Size Land_Area(Sq.Km) Pop_density_per_Sqkm
# 0           Mombasa  1208333            219.9                 5495
# 1             Kwale   866820           8267.1                  105
# 2            Kilifi  1453787          12539.7                  116
# 3        Tana River   315943          37950.5                    8
# 4              Lamu   143920           6253.3                   23
# 5      Taita-Taveta   340671            17152                   20
# 6           Garissa   841353            44736                   19
# 7             Wajir   781263          56773.1                   14
# 8           Mandera   867457          25939.8                   33
# 9          Marsabit   459785          70944.1                    6
# 10           Isiolo   268002          25350.6                   11
# 11             Meru  1545714           7006.3                  221
# 12    Tharaka-Nithi   393177           2564.4                  153
# ...

# %% [markdown]
# ### 2nd Dataset

# %% [markdown]
# #### Distribution of population by Sex and County

# %%
df2=pd.read_csv('https://open.africa/dataset/9b94fe50-9d75-4b92-be00-6354c6e6cc88/resource/68dc2815-c9de-47ec-92d9-61f0be213ed8/download/distribution-of-population-by-sex-and-county-2019-census-volume-ii.csv')

# %%
df2.head()
# Out:
#        County     Total     Male     Female  Sex Intersex
# 0       Kenya  47564296  23548056  24014716          1524
# 1     Mombasa   1208333    610257    598046            30
# 2       Kwale    866820    425121    441681            18
# 3      Kilifi   1453787    704089    749673            25
# 4  Tana River    315943    158550    157391             2

# %%
df2.drop(df2.index[0], inplace=True)

# %%
df2.head()
# Out:
#        County    Total   Male   Female  Sex Intersex
# 1     Mombasa  1208333  610257  598046            30
# 2       Kwale   866820  425121  441681            18
# 3      Kilifi  1453787  704089  749673            25
# 4  Tana River   315943  158550  157391             2
# 5        Lamu   143920   76103   67813             4

# %%
df2.reset_index(drop= True, inplace=True)

# %%
df2.head()
# Out:
#        County    Total   Male   Female  Sex Intersex
# 0     Mombasa  1208333  610257  598046            30
# 1       Kwale   866820  425121  441681            18
# 2      Kilifi  1453787  704089  749673            25
# 3  Tana River   315943  158550  157391             2
# 4        Lamu   143920   76103   67813             4

# %% [markdown]
# ### 3rd dataset:

# %% [markdown]
# #### Distribution of population, number of Housholds and Average household size by county

# %%
df3=pd.read_csv("https://open.africa/dataset/9b94fe50-9d75-4b92-be00-6354c6e6cc88/resource/111a3d9d-c676-4d5a-9600-d5acb1250b87/download/population-houseshold-data.csv")

# %%
df3.head(15)
# Out:
#                                            Unnamed: 0  Unnamed: 1  \
# 0   Distribution of Population, Number of Househol...         NaN
# 1   Source: 2019 Kenya Population and Housing Cens...         NaN
# 2   https://www.knbs.or.ke/?wpdmpro=2019-kenya-pop...         NaN
# 3   Population, Households, Household size, County...         NaN
# 4                                                 NaN         NaN
# 5                                                name  Population
# 6                                               Kenya    47213282
# 7                                             Mombasa     1190987
# 8                                               Kwale      858748
# 9                                              Kilifi     1440958
# 10                                         Tana River      314710
# 11                                               Lamu      141909
# 12                                       Taita-Taveta      335747
# ...

# %%
df3.columns=('County_Name','Pop_Size','No. of Households','Avg_Household_Size')

# %%
df3.drop(df3.index[:7], inplace=True)

# %%
df3.reset_index(drop= True, inplace=True)

# %%
df3.head()
# Out:
#   County_Name Pop_Size No. of Households Avg_Household_Size
# 0     Mombasa  1190987            378422                 31
# 1       Kwale   858748            173176                 50
# 2      Kilifi  1440958            298472                 48
# 3  Tana River   314710             68242                 46
# 4        Lamu   141909             37963                 37

# %% [markdown]
# ### 4th Dataset

# %% [markdown]
# #### Distribution of Population by Age and Sex

# %%
df4=pd.read_csv("https://open.africa/dataset/9b94fe50-9d75-4b92-be00-6354c6e6cc88/resource/85b587f4-48c5-4fa5-b15b-c3f97942f66a/download/distribution-of-population-by-age-and-sex-kenya-2019-census-volume-iii.csv")

# %%
df4.head(20)
# Out:
#        Age        Male      Female Intersex  Unnamed: 4  Unnamed: 5
# 0    Total  23,548,056  24,014,716    1,524         NaN         NaN
# 1        0     552,508     552,528       38         NaN         NaN
# 2        1     580,856     573,920       29         NaN         NaN
# 3        2     614,005     610,705       33         NaN         NaN
# 4        3     619,989     621,941       26         NaN         NaN
# 5        4     638,986     627,675       28         NaN         NaN
# 6    0 - 4   3,006,344   2,986,769      154         NaN         NaN
# 7        5     626,157     610,459       40         NaN         NaN
# 8        6     635,924     635,942       30         NaN         NaN
# 9        7     609,615     601,301       24         NaN         NaN
# 10       8     618,618     616,833       46         NaN         NaN
# 11       9     626,637     620,981       36         NaN         NaN
# 12   5 - 9   3,116,951   3,085,516      176         NaN         NaN
# ...

# %%
df4.tail()
# Out:
#             Age   Male  Female Intersex  Unnamed: 4  Unnamed: 5
# 118          98  1,137   2,026        -         NaN         NaN
# 119          99  1,856   4,734        -         NaN         NaN
# 120       95-99  9,770  18,236        -         NaN         NaN
# 121        100+  3,876  10,164        -         NaN         NaN
# 122  Not Stated    385     297        5         NaN         NaN

# %% [markdown]
# #### drop columns from df4 that have all Null values

# %%
df4.dropna(axis=1, inplace=True)

# %%
df4
# Out:
#             Age        Male      Female Intersex
# 0         Total  23,548,056  24,014,716    1,524
# 1             0     552,508     552,528       38
# 2             1     580,856     573,920       29
# 3             2     614,005     610,705       33
# 4             3     619,989     621,941       26
# ..          ...         ...         ...      ...
# 118          98       1,137       2,026        -
# 119          99       1,856       4,734        -
# 120       95-99       9,770      18,236        -
# 121        100+       3,876      10,164        -
# 122  Not Stated         385         297        5
#
# [123 rows x 4 columns]

# %%
df4.to_csv('ageandsex.csv')

# %% [markdown]
# #### Working with df1,2 and 3 first as they have common columns
#
# ##### joining columns, changing column datatypes,checking for Null values

# %%
df.head()
# Out:
#   County_Name Pop_Size Land_Area(Sq.Km) Pop_density_per_Sqkm
# 0     Mombasa  1208333            219.9                 5495
# 1       Kwale   866820           8267.1                  105
# 2      Kilifi  1453787          12539.7                  116
# 3  Tana River   315943          37950.5                    8
# 4        Lamu   143920           6253.3                   23

# %%
df2.head()
# Out:
#        County    Total   Male   Female  Sex Intersex
# 0     Mombasa  1208333  610257  598046            30
# 1       Kwale   866820  425121  441681            18
# 2      Kilifi  1453787  704089  749673            25
# 3  Tana River   315943  158550  157391             2
# 4        Lamu   143920   76103   67813             4

# %%
df3.head()
# Out:
#   County_Name Pop_Size No. of Households Avg_Household_Size
# 0     Mombasa  1190987            378422                 31
# 1       Kwale   858748            173176                 50
# 2      Kilifi  1440958            298472                 48
# 3  Tana River   314710             68242                 46
# 4        Lamu   141909             37963                 37

# %%
df2.columns.values.tolist()
# Out:
# ['County', 'Total', 'Male ', 'Female', 'Sex Intersex']

# %%
df['Male']=df2['Male ']
df['Female']=df2['Female']
df['Intersex']=df2['Sex Intersex']

# %%
df.head()
# Out:
#   County_Name Pop_Size Land_Area(Sq.Km) Pop_density_per_Sqkm    Male  Female  \
# 0     Mombasa  1208333            219.9                 5495  610257  598046
# 1       Kwale   866820           8267.1                  105  425121  441681
# 2      Kilifi  1453787          12539.7                  116  704089  749673
# 3  Tana River   315943          37950.5                    8  158550  157391
# 4        Lamu   143920           6253.3                   23   76103   67813
#
#    Intersex
# 0        30
# 1        18
# 2        25
# 3         2
# 4         4

# %%
df3.columns.values.tolist()
#df3.columns.get_loc('No. of Households')
# Out:
# ['County_Name', 'Pop_Size', 'No. of Households', 'Avg_Household_Size']

# %%
df['No_of_Households']=df3['No. of Households']
df['Avg_Household_Size']=df3['Avg_Household_Size']

# %%
df
# Out:
#         County_Name  Pop_Size  Land_Area(Sq.Km)  Pop_density_per_Sqkm  \
# 0           Mombasa   1208333             219.9                  5495
# 1             Kwale    866820            8267.1                   105
# 2            Kilifi   1453787           12539.7                   116
# 3        Tana River    315943           37950.5                     8
# 4              Lamu    143920            6253.3                    23
# 5      Taita-Taveta    340671           17152.0                    20
# 6           Garissa    841353           44736.0                    19
# 7             Wajir    781263           56773.1                    14
# 8           Mandera    867457           25939.8                    33
# 9          Marsabit    459785           70944.1                     6
# 10           Isiolo    268002           25350.6                    11
# 11             Meru   1545714            7006.3                   221
# ...

# %%
# del df['Avg Household Size']

# %%
df.dtypes
# Out:
# County_Name              object
# Pop_Size                  int64
# Land_Area(Sq.Km)        float64
# Pop_density_per_Sqkm      int64
# Male                      int64
# Female                    int64
# Intersex                  int64
# No_of_Households          int64
# Avg_Household_Size       object
# dtype: object

# %%
#convert column to numeric
df[["Pop_Size","Land_Area(Sq.Km)","Pop_density_per_Sqkm","No_of_Households","Avg_Household_Size"]]=df[["Pop_Size","Land_Area(Sq.Km)","Pop_density_per_Sqkm","No_of_Households","Avg_Household_Size"]].apply(pd.to_numeric)

# %%
df.dtypes
# Out:
# County_Name              object
# Pop_Size                  int64
# Land_Area(Sq.Km)        float64
# Pop_density_per_Sqkm      int64
# Male                      int64
# Female                    int64
# Intersex                  int64
# No_of_Households          int64
# Avg_Household_Size        int64
# dtype: object

# %%
# household size values looks abit off
#according to https://www.africageoportal.com/datasets/esri::kenya-average-household-size the avg. household 
#size 4.0 and https://www.prb.org/international/indicator/hh-size-av/map/country/ list the world avg as 4.0
# verifying that by dividing the pop.size column and no. of household columns


dfavgsize= df['Pop_Size']/df['No_of_Households']

dfavgsize
# Out:
# 0     3.193083
# 1     5.005428
# 2     4.870765
# 3     4.629744
# 4     3.791060
# 5     3.532869
# 6     5.950415
# 7     6.106861
# 8     6.897553
# 9     5.933092
# 10    4.614995
# 11    3.625373
# 12    3.578891
# 13    3.330355
# 14    4.321056
# 15    3.533049
# 16    4.036690
# 17    3.552247
# 18    3.060528
# 19    2.989456
# 20    3.321671
# 21    3.040254
# 22    5.634462
# 23    5.347136
# 24    4.708345
# 25    4.424958
# 26    3.814437
# 27    4.551126
# 28    4.441302
# 29    4.678448
# 30    3.473950
# 31    3.509806
# 32    4.801962
# 33    3.535466
# 34    4.376793
# 35    4.666832
# 36    4.311055
# 37    4.115461
# 38    4.656044
# 39    4.510078
# 40    3.961671
# 41    3.842371
# 42    4.319826
# 43    4.648563
# 44    4.112461
# 45    4.019247
# 46    2.917983
# dtype: float64

# %%
# Comparing the output above and the avg. household size column, a decimal was ommitted
# therefore we can divide the values of avg. household size column by 10
df['Avg_Household_Size']=df['Avg_Household_Size']/10

# %%
df
# Out:
#         County_Name  Pop_Size  Land_Area(Sq.Km)  Pop_density_per_Sqkm  \
# 0           Mombasa   1208333             219.9                  5495
# 1             Kwale    866820            8267.1                   105
# 2            Kilifi   1453787           12539.7                   116
# 3        Tana River    315943           37950.5                     8
# 4              Lamu    143920            6253.3                    23
# 5      Taita-Taveta    340671           17152.0                    20
# 6           Garissa    841353           44736.0                    19
# 7             Wajir    781263           56773.1                    14
# 8           Mandera    867457           25939.8                    33
# 9          Marsabit    459785           70944.1                     6
# 10           Isiolo    268002           25350.6                    11
# 11             Meru   1545714            7006.3                   221
# ...

# %%
#writing df to an excel file to save it as a backup

df.to_csv('popcensusdata1.csv')

# %%
df.describe()
# Out:
#            Pop_Size  Land_Area(Sq.Km)  Pop_density_per_Sqkm          Male  \
# count  4.700000e+01         47.000000             47.000000  4.700000e+01
# mean   1.012006e+06      12359.074468            509.148936  5.010225e+05
# std    6.932427e+05      17366.002689           1175.429468  3.423677e+05
# min    1.439200e+05        219.900000              6.000000  7.610300e+04
# 25%    6.095050e+05       2530.350000             52.500000  3.031095e+05
# 50%    8.936810e+05       3325.000000            221.000000  4.507410e+05
# 75%    1.156724e+06      14845.850000            416.000000  5.699920e+05
# max    4.397073e+06      70944.100000           6247.000000  2.192452e+06
#
#              Female    Intersex  No_of_Households  Avg_Household_Size
# count  4.700000e+01   47.000000      4.700000e+01           47.000000
# mean   5.109514e+05   32.425532      2.583811e+05            4.231915
# std    3.513158e+05   38.490961      2.344552e+05            0.884186
# ...

# %%
df['Pop_density_per_Sqkm'].describe()
# Out:
# count      47.000000
# mean      509.148936
# std      1175.429468
# min         6.000000
# 25%        52.500000
# 50%       221.000000
# 75%       416.000000
# max      6247.000000
# Name: Pop_density_per_Sqkm, dtype: float64

# %%
df.describe()

# %%
#checking for any null values
df.isnull().values.any()
# Out:
# False

# %%
#reading in the cleaned csv file to work with data stored locally and also not have to run entire notebook each time

df=pd.read_csv('popcensusdata1.csv')

# %%
df
# Out:
#         County_Name  Pop_Size  Land_Area(Sq.Km)  Pop_density_per_Sqkm  \
# 0           Mombasa   1208333             219.9                  5495
# 1             Kwale    866820            8267.1                   105
# 2            Kilifi   1453787           12539.7                   116
# 3        Tana River    315943           37950.5                     8
# 4              Lamu    143920            6253.3                    23
# 5      Taita-Taveta    340671           17152.0                    20
# 6           Garissa    841353           44736.0                    19
# 7             Wajir    781263           56773.1                    14
# 8           Mandera    867457           25939.8                    33
# 9          Marsabit    459785           70944.1                     6
# 10           Isiolo    268002           25350.6                    11
# 11             Meru   1545714            7006.3                   221
# ...

# %% [markdown]
# ### 3.0 Data Visualization
# In this section, i plot graphs with the clean datasets. I also note some of the insights that become visible from the graphs.

# %%
# importing library for plotting graphs
import matplotlib.pyplot as plt

# %% [markdown]
# ###### i. Population Density per county

# %%
bins=[500000,1000000,1500000,2000000,2500000,3000000,3500000,4000000,4500000]
df.plot(kind='bar', x='County_Name',y='Pop_Size', width=0.5)
#plt.bar(df['County_Name'],df['Pop_Size'],width=0.5)
plt.yticks(bins)
plt.title ('Population density per county County')
plt.xlabel('Counties')
plt.ylabel('Population density (million)')
plt.figure(figsize=(300,6))
#plt.xticks(fontsize=0.5)
#plt.xticks(rotation=25)


#plt.tick_params(axis='x', which='major', labelsize=3)
plt.show()

# %% [markdown]
# from the bar graph the most populous county in Kenya is Nairobi, followed by Kiambu, Nakuru and Kakamega
# The least populous county is Lamu, followed by isiolo, Tana River,Taita-Taveta,samburu, Tharaka Nithi.
# It is interesting to note that Tharaka Nithi county is among the least populous counties contrary to popular belief

# %% [markdown]
# ###### ii. Comparison of county sizes

# %%
#Land area per county
df.plot(kind='bar', x='County_Name',y='Land_Area(Sq.Km)', width=0.5)
plt.title('Size of Counties (Land Area in Sqkm)')
plt.xlabel('County')
plt.ylabel('Pop. Density (Sqkm)')
plt.show()

# %% [markdown]
# Turkana and Marsabit counties cover the largest area per sqm followed by wajir, Garissa and Tana river.
# Mombasa,Nairobi and Vihiga counties covers the least land area per sqkm even though from the earlier graph  Nairobi
# is the most populous county

# %% [markdown]
# ###### iii. Comparison of Pop. Density per county

# %%
#Population (density per sqkm) per county
df.plot(kind='bar', x='County_Name',y='Pop_density_per_Sqkm', width=0.5)
plt.title('Population Density per County per sqkm')
plt.xlabel('County')
plt.ylabel('Pop. Density (Sqkm)')
plt.show ()

# %% [markdown]
# Mombasa and Nairobi are the most densely populated counties; This was to be expected
# since from my earlier Vizualizations they are the most populous but cover the least land area
# per sqkm
# Tana river and Marsabit have the lowest population density (disappearing from view) followed by Lamu, Taita taveta, Garisss,wajir,
# Mandera,isiolo, Turkana, West pokot, Samburu, Baringo, Laikipia, Narok,Kajiado;
# On Revisting the data,Tana river and Marsabit have less than 10 people per sq km

# %% [markdown]
# ###### iv. No. of Households per county

# %%
df.plot(kind='bar', x='County_Name',y='No_of_Households', width=0.5)
plt.title('No. Of Households per county')
plt.xlabel('County')
plt.ylabel('No. of Households')
plt.show ()

# %% [markdown]
# Nairobi has the most no. of households followed by kiambu,Nakuru and Meru counties while the lowest no. of households
# are in lamu, isiolo,samburu
# The graph is an exact replica of the pop. size per county graph; hence suggesting a linear r/ship between pop. size and
# number of households; let's check that with the next graph

# %%
df.plot(kind='line', x='Pop_Size',y='No_of_Households')
plt.title('Pop. Size vs No. Of Households')
plt.xlabel('Pop. Size')
plt.ylabel('No. of Households')
plt.show ()

# %% [markdown]
# As expected, graph shows that no. of household increases with pop. size

# %% [markdown]
# ###### v. Average Household Size per county

# %%
# Avg. Household size
df.plot(kind='bar', x='County_Name',y='Avg_Household_Size', width=0.5)
plt.title('Avg Household Size')
plt.xlabel('County')
plt.ylabel('Avg Household Size')
plt.show ()

# %% [markdown]
# The graph suggests that across the counties,there is not a huge disparity in the average household size.
# However some of the counties that had very low pop. sizes seem to have the
# largest household sizes; mandera,west pokot, mandera
# Nairobi County (which is the most densely populated and has the highest pop.size) has the least avg. household size

# %%
df.describe()
# Out:
#        Unnamed: 0      Pop_Size  Land_Area(Sq.Km)  Pop_density_per_Sqkm  \
# count   47.000000  4.700000e+01         47.000000             47.000000
# mean    23.000000  1.012006e+06      12359.074468            509.148936
# std     13.711309  6.932427e+05      17366.002689           1175.429468
# min      0.000000  1.439200e+05        219.900000              6.000000
# 25%     11.500000  6.095050e+05       2530.350000             52.500000
# 50%     23.000000  8.936810e+05       3325.000000            221.000000
# 75%     34.500000  1.156724e+06      14845.850000            416.000000
# max     46.000000  4.397073e+06      70944.100000           6247.000000
#
#                Male        Female    Intersex  No_of_Households  \
# count  4.700000e+01  4.700000e+01   47.000000      4.700000e+01
# mean   5.010225e+05  5.109514e+05   32.425532      2.583811e+05
# std    3.423677e+05  3.513158e+05   38.490961      2.344552e+05
# ...

# %% [markdown]
# ###### vi.Gender proportions across counties

# %%
df[['County_Name','Male','Female']].set_index('County_Name').plot(kind='bar', stacked=True, width=0.7)
plt.figure(figsize=(300,6))

#df[['County_Name','Male','Female']].plot(kind='bar',x='County_Name' ,stacked=True, width=0.7)

plt.figure(figsize=(300,10))
plt.title('Gender proportions across counties')

plt.show()

# %%
The male-female ratios across counties are almost equal.There is no county that has a significantly 
large number of one gender compared to the other and indeed this can be seen from the data

# %% [markdown]
# ###### vii. National gender proportions

# %%
ageandsex=pd.read_csv('ageandsex.csv')

# %%
ageandsex
# Out:
#             Age      Male    Female Intersex
# 0         Total  23548056  24014716     1524
# 1             0    552508    552528       38
# 2             1    580856    573920       29
# 3             2    614005    610705       33
# 4             3    619989    621941       26
# ..          ...       ...       ...      ...
# 118          98      1137      2026        -
# 119          99      1856      4734        -
# 120       95-99      9770     18236        -
# 121        100+      3876     10164        -
# 122  Not Stated       385       297        5
#
# [123 rows x 4 columns]

# %%
ageandsex.dtypes
# Out:
# Age         object
# Male         int64
# Female       int64
# Intersex    object
# dtype: object

# %%
ageandsex
# Out:
#             Age        Male      Female Intersex
# 0         Total  23,548,056  24,014,716    1,524
# 1             0     552,508     552,528       38
# 2             1     580,856     573,920       29
# 3             2     614,005     610,705       33
# 4             3     619,989     621,941       26
# ..          ...         ...         ...      ...
# 118          98       1,137       2,026        -
# 119          99       1,856       4,734        -
# 120       95-99       9,770      18,236        -
# 121        100+       3,876      10,164        -
# 122  Not Stated         385         297        5
#
# [123 rows x 4 columns]

# %%
ageandsex.dtypes
# Out:
# Age         object
# Male         int64
# Female       int64
# Intersex    object
# dtype: object

# %%
#extracting the total values for male nd female from above dataframe and creating a series for plotting a pie chart
male=ageandsex['Male'].iloc[0]
female=ageandsex['Female'].iloc[0]
male
lst=[male,female]
gender=pd.DataFrame(lst)

gender.insert(loc=0,column='Sex',value=('Male','Female'))
gender[0]=(gender[0]/(male+female))*100
gender
# Out:
#       Sex          0
# 0    Male  49.509427
# 1  Female  50.490573

# %%
gender[0].plot(kind='pie',labels=gender['Sex'],autopct='%1.2f%%',figsize=(8,8),fontsize=10, subplots='True')
plt.title('National gender proportions')
# Out:
# Text(0.5, 1.0, 'National gender proportions')

# %% [markdown]
# The national female-male proportions are almost equal
# contrary to a common notion that females are significantly more than males

# %% [markdown]
# ### 4.0 Conclusion
# i.The most populous county is Nairobi and the least populous county is Lamu
#
# ii.Turkana and Marsabit counties cover the largest land area per sqm while Nairobi covers the least land area per sqm
#
# iii.Although across the counties there isn't a huge disparity in the average household sizes,
# including in counties that are the least populous,counties that have very low pop. sizes such as
# mandera and west pokot seem to have the largest household sizes(of 6-7 people). On the other hand, Nairobi County which has the highest pop.size, has the least avg. household size of 3 people.
#
# iv.The male-female ratios across counties are almost equal.There is no county that has a significantly
# large number of one gender compared to the other.
#
# v.The national female-male proportions are almost equal
#
# This project was an exploration of just a few data sets from the Kenya population and housing census data. More information can be gleaned by exploring more data sets. It would be interesting for example to
# visualize datasets on socio-economic standards and education status.The population data can also be combined and explored with other existing data in various sectors such health, agriculture, Education e.t.c to provide even more useful information that can be used by the government for planning and
# service delivery improvement.
